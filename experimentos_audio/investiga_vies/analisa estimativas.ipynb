# %%
# %matplotlib notebook

# %%
import pandas as pd
from analisa import plota_estimativas_media, plota_estimativas_std

# %%
suj = pd.read_csv('./Boris2026fev25blin/estimativas_dicoico_Boris2026fev25blin_03_02_26__11_07_11.csv')
suj_outro = pd.read_csv('./Pavao2026fev25blin/estimativas_dicoico_Pavao2026fev25blin_03_02_26__11_27_36_BORIS.csv') 

ax = plota_estimativas_media(suj, diagonal=True, label='Boris blin')
plota_estimativas_media(suj_outro, ax, label='Boris com Pavao blin')
ax.legend()

ax = plota_estimativas_std(suj, label='Boris blin')
plota_estimativas_std(suj_outro, ax, label='Boris com Pavao blin')
ax.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
